# %%
import matplotlib.pyplot as plt
import random
import numpy as np
import math

# %% [markdown]
# ## 1.

# %%
R = 1

# %% [markdown]
# ## A.

# %%
def circle_function(x):
    f_x = math.sqrt(2*x - x**2) + 1
    return f_x

# %% [markdown]
# For this exercise $ m = 2 $ and $ [a,b] = [0,2] $

# %%
m = 2
X1 = []
Y1 = []
for i in range(2000):
    x = random.uniform(0,2)
    y = random.uniform(0,2)
    f_x = circle_function(x)
    if y <= (f_x / m):
        X.append(x)
        Y.append(y)

# %%
plt.scatter(X,Y)

# %% [markdown]
# ## B.

# %%
X2 = []
Y2 = []
for i in range(2000):
    r = random.random()
    theta = random.random()
    x = r*math.cos(2*math.pi*theta)
    y = r*math.sin(2*math.pi*theta)
    X2.append(x)
    Y2.append(y)

# %%
plt.scatter(X2, Y2)

# %% [markdown]
# ## C.

# %%
X3 = []
Y3 = []
for i in range(2000):
    F_r = random.random()
    theta = random.random()
    r = math.sqrt(F_r)
    x = r*math.cos(2*math.pi*theta)
    y = r*math.sin(2*math.pi*theta)
    X2.append(x)
    Y2.append(y)

# %%
plt.scatter(X2, Y2)

# %% [markdown]
# In the plot above points are distributed more uniformly than in B and thats because r doesn't follow uniform distribution.

# %% [markdown]
# ## 2.

# %% [markdown]
# ## A.

# %%
A = 10**4
alpha = -3/2
X4 = []
Y4 = []
for i in range(100000):
    F_x = random.random()
    x = math.sqrt(2*A/(2*A - F_x))
    y = A*x**alpha
    X4.append(x)
    Y4.append(y)

# %%
plt.plot(X4, Y4)
